# %% [markdown]
# <a href="https://colab.research.google.com/github/jamcabral/pos_puc_minas_engenharia_de_dados/blob/main/02%20NoSQL/Unidade%202/colab/Unidade2_Nosql_Jammesson_Cabral.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('lotofacil_updated.csv')

# %%
df.columns
# Out:
# Index(['Concurso', 'Data_Sorteio', 'Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5',
#        'Bola6', 'Bola7', 'Bola8', 'Bola9', 'Bola10', 'Bola11', 'Bola12',
#        'Bola13', 'Bola14', 'Bola15', 'Arrecadacao_Total',
#        'Ganhadores_15_Numeros', 'Cidade', 'Ganhadores_14_Numeros',
#        'Ganhadores_13_Numeros', 'Ganhadores_12_Numeros',
#        'Ganhadores_11_Numeros', 'Valor_Rateio_15_Numeros',
#        'Valor_Rateio_14_Numeros', 'Valor_Rateio_13_Numeros',
#        'Valor_Rateio_12_Numeros', 'Valor_Rateio_11_Numeros',
#        'Acumulado_15_Numeros', 'Estimativa_Premio',
#        'Valor_Acumulado_Especial'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2829 entries, 0 to 2828
# Data columns (total 32 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Concurso                  2829 non-null   int64
#  1   Data_Sorteio              2829 non-null   object
#  2   Bola1                     2829 non-null   int64
#  3   Bola2                     2829 non-null   int64
#  4   Bola3                     2829 non-null   int64
#  5   Bola4                     2829 non-null   int64
#  6   Bola5                     2829 non-null   int64
#  7   Bola6                     2829 non-null   int64
#  8   Bola7                     2829 non-null   int64
#  9   Bola8                     2829 non-null   int64
#  10  Bola9                     2829 non-null   int64
#  11  Bola10                    2829 non-null   int64
#  12  Bola11                    2829 non-null   int64
#  13  Bola12                    2829 non-null   int64
# ...

# %%
df.describe()
# Out:
#           Concurso        Bola1        Bola2        Bola3        Bola4  \
# count  2829.000000  2829.000000  2829.000000  2829.000000  2829.000000
# mean   1415.000000     1.623895     3.257335     4.879463     6.523860
# std     816.806281     0.925405     1.296096     1.534366     1.712716
# min       1.000000     1.000000     2.000000     3.000000     4.000000
# 25%     708.000000     1.000000     2.000000     4.000000     5.000000
# 50%    1415.000000     1.000000     3.000000     5.000000     6.000000
# 75%    2122.000000     2.000000     4.000000     6.000000     8.000000
# max    2829.000000     7.000000     9.000000    12.000000    13.000000
#
#              Bola5        Bola6        Bola7        Bola8        Bola9  ...  \
# count  2829.000000  2829.000000  2829.000000  2829.000000  2829.000000  ...
# mean      8.159774     9.792153    11.386709    13.016614    14.611877  ...
# std       1.813803     1.859053     1.890659     1.911424     1.929984  ...
# ...

# %%
df.describe(include='object')
# Out:
#        Data_Sorteio Arrecadacao_Total               Cidade  \
# count          2829              2829                 2540
# unique         2829              2402                 2113
# top      29/09/2003            R$0,00  CANAL ELETRONICO --
# freq              1               428                   39
#
#        Valor_Rateio_15_Numeros Valor_Rateio_14_Numeros  \
# count                     2829                    2829
# unique                    2541                    2802
# top                     R$0,00              R$1.544,46
# freq                       289                       3
#
#        Valor_Rateio_13_Numeros Valor_Rateio_12_Numeros  \
# count                     2829                    2829
# unique                       6                       6
# top                    R$25,00                 R$10,00
# freq                       912                     912
#
#        Valor_Rateio_11_Numeros Acumulado_15_Numeros Estimativa_Premio  \
# ...

# %%
df_numeros_sorteados = df[['Concurso', 'Data_Sorteio', 'Bola1', 'Bola2', 'Bola3', 'Bola4', 'Bola5', 'Bola6', 'Bola7', 'Bola8', 'Bola9',
                          'Bola10', 'Bola11', 'Bola12', 'Bola13', 'Bola14', 'Bola15']]

# %%
df_numeros_sorteados
# Out:
#       Concurso Data_Sorteio  Bola1  Bola2  Bola3  Bola4  Bola5  Bola6  Bola7  \
# 0            1   29/09/2003      2      3      5      6      9     10     11
# 1            2   06/10/2003      1      4      5      6      7      9     11
# 2            3   13/10/2003      1      4      6      7      8      9     10
# 3            4   20/10/2003      1      2      4      5      8     10     12
# 4            5   27/10/2003      1      2      4      8      9     11     12
# ...        ...          ...    ...    ...    ...    ...    ...    ...    ...
# 2824      2825   30/05/2023      2      3      4      6      7      8      9
# 2825      2826   31/05/2023      1      2      3      5      7      9     11
# 2826      2827   01/06/2023      1      2      3      5      6      7     10
# 2827      2828   02/06/2023      1      5      6      8     11     12     14
# 2828      2829   03/06/2023      2      3      5      6      7      8      9
#
# ...

# %%
df_ganhadores = df[['Concurso', 'Data_Sorteio', 'Ganhadores_11_Numeros', 'Ganhadores_12_Numeros', 'Ganhadores_13_Numeros', 'Ganhadores_14_Numeros', 'Ganhadores_15_Numeros']]

# %%
df_ganhadores
# Out:
#       Concurso Data_Sorteio  Ganhadores_11_Numeros  Ganhadores_12_Numeros  \
# 0            1   29/09/2003                 257593                  48807
# 1            2   06/10/2003                 478188                  81252
# 2            3   13/10/2003                 608211                  96244
# 3            4   20/10/2003                 706657                 123912
# 4            5   27/10/2003                 860992                 195636
# ...        ...          ...                    ...                    ...
# 2824      2825   30/05/2023                 494428                  86514
# 2825      2826   31/05/2023                 622078                 143612
# 2826      2827   01/06/2023                 745821                 129877
# 2827      2828   02/06/2023                 576531                  93873
# 2828      2829   03/06/2023                 887338                 177160
#
#       Ganhadores_13_Numeros  Ganhadores_14_Numeros  Ganhadores_15_Numeros
# ...

# %%
df_premio = df[['Concurso', 'Data_Sorteio', 'Valor_Rateio_11_Numeros', 'Valor_Rateio_12_Numeros', 'Valor_Rateio_13_Numeros', 'Valor_Rateio_14_Numeros', 'Valor_Rateio_15_Numeros']]

# %%
df_premio
# Out:
#       Concurso Data_Sorteio Valor_Rateio_11_Numeros Valor_Rateio_12_Numeros  \
# 0            1   29/09/2003                  R$2,00                  R$4,00
# 1            2   06/10/2003                  R$2,00                  R$4,00
# 2            3   13/10/2003                  R$2,00                  R$4,00
# 3            4   20/10/2003                  R$2,00                  R$4,00
# 4            5   27/10/2003                  R$2,00                  R$4,00
# ...        ...          ...                     ...                     ...
# 2824      2825   30/05/2023                  R$6,00                 R$12,00
# 2825      2826   31/05/2023                  R$6,00                 R$12,00
# 2826      2827   01/06/2023                  R$6,00                 R$12,00
# 2827      2828   02/06/2023                  R$6,00                 R$12,00
# 2828      2829   03/06/2023                  R$6,00                 R$12,00
#
# ...

# %%
#df_numeros_sorteados.to_json('numeros_sorteados.json', orient="index")
numeros_sorteados_json = df_numeros_sorteados.to_json(orient='records')
with open('numeros_sorteados.json', 'w') as f:
    f.write(numeros_sorteados_json)

# %%
#df_ganhadores.to_json('qtd_ganhadores.json', orient="index")
qtd_ganhadores_json = df_ganhadores.to_json(orient='records')
with open('qtd_ganhadores.json', 'w') as f:
    f.write(qtd_ganhadores_json)

# %%
#df_premio.to_json('valores_sorteios.json', orient="index")
valores_sorteios_json = df_premio.to_json(orient='records')
with open('valores_sorteios.json', 'w') as f:
    f.write(valores_sorteios_json)

# %%
# valores_sorteios_json = df_premio.to_json(orient='records')
# with open('valores_sorteios.json', 'w') as f:
#     f.write(valores_sorteios_json)
